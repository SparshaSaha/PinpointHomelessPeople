# %%
import json
from pprint import pprint
import matplotlib.pyplot as plt
import gmplot
import numpy as np
import math
from pprint import pprint
import matplotlib.pyplot as plt

# %%
with open('data.json') as data_file:    
    data = json.load(data_file)
z=data['Homeless']
coordinates=[]
for k,v in z.items():
    loc=(v['loc_data'])
    u=[]
    u.append(float(loc['latitude']))
    u.append(float(loc['longitude']))
    coordinates.append(u)

pprint(coordinates)
# Out:
# [[29.57883661345322, 75.80317061394452],
#  [15.397881371454858, 78.68989270180464],
#  [21.898905858887808, 87.12773334234954],
#  [24.16703028029368, 88.00884537398815],
#  [20.818320159423624, 85.45898761600256],
#  [12.794655923277306, 80.11362735182047],
#  [23.09666162331421, 86.93040624260901],
#  [19.915592140374564, 83.2428177818656],
#  [33.31484974760119, 76.0959092527628],
#  [28.94070685053963, 76.18468701839447],
#  [23.65339873033804, 88.12037866562603],
#  [26.903955092379306, 75.90155705809593],
#  [30.211209255801734, 74.85453899949789],
#  [20.516149617354145, 82.67631344497204],
#  [12.843598056769167, 80.153842382133],
#  [22.455396250583913, 88.30782484263182],
#  [36.83414915357137, 10.168730802834034],
#  [6.184225161803403, -0.43260645121335983],
#  [12.845537800788636, 80.1537089422345],
#  [26.532343253594487, 75.13489320874214],
#  [24.108553154872805, 84.08988621085882],
#  [28.4550059222099, 75.71512944996357],
#  [20.27331908058933, 83.2608013227582],
# ...

# %%
def get_distance(p1,p2):
    dist=(p1[0]-p2[0])**2+(p1[1]-p2[1])**2
    return math.sqrt(dist)

# %%
points=coordinates
k=3
heads=[]
clusters=[]
for i in range(k):
    heads.append(points[i])

new_clusters=[[],[],[]]
    

new_heads=[]
c=3
while c>0:
    for i in points:
        mini=999999
        c_no=0
        for j in range(k):
            h=get_distance(i,heads[j])
            if h<mini:
                mini=h
                c_no=j
        if i not in heads:
            new_clusters[c_no].append(i)
    pprint(new_clusters)
  
    for i in new_clusters:
        x_c=0
        y_c=0
        for j in i:
            x_c+=j[0]
            y_c+=j[1]
        if len(i) !=0:
            x_c=x_c/float(len(i))
            y_c=y_c/float(len(i))
        u=[x_c,y_c]
        new_heads.append(u)
        
    #pprint(new_heads)
    if clusters==new_clusters:
        break
    else:
        clusters=new_clusters
        new_clusters=[[],[],[]]
        heads=new_heads
        new_heads=[]
   
    pprint(heads)
    print('\n')
colors=['ro','go','yo','bo','ko','co']

for i in range(k):
    for j in new_clusters[i]:
        plt.plot(j[0],j[1],colors[i])
plt.show()
# Out:
# [[[33.31484974760119, 76.0959092527628],
#   [28.94070685053963, 76.18468701839447],
#   [26.903955092379306, 75.90155705809593],
#   [30.211209255801734, 74.85453899949789],
#   [36.83414915357137, 10.168730802834034],
#   [26.532343253594487, 75.13489320874214],
#   [28.4550059222099, 75.71512944996357],
#   [23.54778427956454, 76.98790535330772],
#   [29.278084385328672, 76.13233800977468],
#   [28.58529984232669, 74.41616009920835],
#   [29.583782015330847, 76.52013882994652],
#   [26.200965569747744, 73.88393707573414],
#   [27.074267043131197, 73.7634328007698],
#   [29.654346454601207, 75.75340960174799],
#   [30.02962788444553, 76.36251915246247],
#   [23.340124674547866, 78.95191233605148],
#   [27.963680125126825, 76.08987160027027],
#   [30.286857311856174, 77.0861291885376],
#   [23.343218432487323, 78.53421024978161],
#   [28.497291926851762, 76.24243564903736],
#   [29.592091937380115, 75.60590218752623],
#   [28.50968905854643, 76.30244806408882],
# ...

# %%
gmap = gmplot.GoogleMapPlotter(25.54, 80.553, 5)
gmap1 = gmplot.GoogleMapPlotter(25.54, 80.553, 5)
gmap2 = gmplot.GoogleMapPlotter(25.54, 80.553, 5)
color=['#FF0000','#000000','#008000']
color_chooser=0

for j in new_clusters[0]:
    gmap.scatter([j[0]], [j[1]], '#FF0000',size=2, marker=True)
color_chooser+=1

for j in new_clusters[1]:
    gmap1.scatter([j[0]], [j[1]], '#008000',size=10, marker=True)
color_chooser+=1


for j in new_clusters[2]:
    gmap2.scatter([j[0]], [j[1]], '#008000',size=10, marker=True)
color_chooser+=1


gmap.draw("mymap.html")
gmap1.draw("mymap1.html")
gmap2.draw("mymap2.html")
